# %% [markdown]
# importation des bibliotheques necessaires et chargement des fichiers "online_retail.csv'

# %%
import pandas as pd
base_2010 ='..\\data\\brute\\online_retail_2010.csv'
base_2011 = '..\\data\\brute\\online_retail_2011.csv'
data_2010 = pd.read_csv(base_2010,sep= ';',parse_dates=['InvoiceDate'],dayfirst=True)
data_2011 = pd.read_csv(base_2011,sep= ';',parse_dates=['InvoiceDate'],dayfirst=True)

# %% [markdown]
# fusion de deux data frame pour faire l'analyse

# %%
data_total = pd.concat([data_2010, data_2011], ignore_index=True)

# %% [markdown]
# Nettoyage de data frame en eliminant les doublons et les lignes qui n'ont pas des customer ID

# %%
data_total.isnull().sum()
data_total=data_total.dropna(subset=['Customer ID'])
data_total=data_total.drop_duplicates()
data_total.describe()
data_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 797885 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      797885 non-null  object
#  1   StockCode    797885 non-null  object
#  2   Description  797885 non-null  object
#  3   Quantity     797885 non-null  int64
#  4   InvoiceDate  797885 non-null  datetime64[ns]
#  5   Price        797885 non-null  float64
#  6   Customer ID  797885 non-null  float64
#  7   Country      797885 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 54.8+ MB

# %% [markdown]
# nettoyage de liste en eliminant les listes avants 2010 pour que le dataframe soit propre

# %%
data_total=data_total[data_total['InvoiceDate']>='01/01/2010 00:00']

# %% [markdown]
# creation de colonne date et mois

# %%
data_total['mois']=data_total['InvoiceDate'].dt.month
data_total['anne']=data_total['InvoiceDate'].dt.year

# %% [markdown]
# Elimination de commande annule (Quantite negatif)

# %%
commande_vendue=data_total[(data_total['Quantity'])>0]
commande_annule=data_total[(data_total['Quantity'])<0]

# %% [markdown]
# creation de colonne revennue

# %%
commande_vendue['Revenue']=commande_vendue['Price']*commande_vendue['Quantity']
commande_vendue.info()
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_6768\937773112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commande_vendue['Revenue']=commande_vendue['Price']*commande_vendue['Quantity']
# <class 'pandas.core.frame.DataFrame'>
# Index: 749216 entries, 45228 to 1067370
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      749216 non-null  object
#  1   StockCode    749216 non-null  object
#  2   Description  749216 non-null  object
#  3   Quantity     749216 non-null  int64
#  4   InvoiceDate  749216 non-null  datetime64[ns]
#  5   Price        749216 non-null  float64
#  6   Customer ID  749216 non-null  float64
#  7   Country      749216 non-null  object
#  8   mois         749216 non-null  int32
#  9   anne         749216 non-null  int32
#  10  Revenue      749216 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int32(2), int64(1), object(4)
# memory usage: 62.9+ MB

# %% [markdown]
# creation de la data frame  à Analyse

# %%
commande_vendue.to_csv('..\\data\\nettoyer\\Online_Retail_a_analyser.csv',index=False)
